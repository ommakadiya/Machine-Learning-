# %%
path = r'/content/cat.png'
import cv2
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image, ImageFilter
import numpy as np
from scipy.ndimage.filters import convolve
# Out:
# /tmp/ipython-input-4267938257.py:7: DeprecationWarning: Please import `convolve` from the `scipy.ndimage` namespace; the `scipy.ndimage.filters` namespace is deprecated and will be removed in SciPy 2.0.0.
#   from scipy.ndimage.filters import convolve

# %%
path = r'/content/download (1).jpg'

# %%
from google.colab.patches import cv2_imshow
img = cv2.imread(path,cv2.IMREAD_GRAYSCALE)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=L size=269x187>

# %%
#kernel declaration
identity=np.array([[0,0,0],[0,1,0],[0,0,0]])
blur=np.ones((9,9),dtype=float)*(1/30)
horizontal=np.array([[1,2,1],[0,0,0],[-1,-1,-1]])

# %%
identity
# Out:
# array([[0, 0, 0],
#        [0, 1, 0],
#        [0, 0, 0]])

# %%
kernel = blur
img2=convolve(img,kernel)

# %%
cv2_imshow(img2)
# Out:
# <PIL.Image.Image image mode=L size=269x187>
